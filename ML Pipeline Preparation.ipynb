# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
import numpy as np

from sqlalchemy import create_engine

import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import classification_report
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/minaferizbegovic/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/minaferizbegovic/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/minaferizbegovic/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql_table('disaster', engine) 
df.head()
X = df['message']
Y = df.iloc[:,4:40]

#res = np.sum(np.array(Y), axis = 1)
#min(res)

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    words = word_tokenize(text)
    tokens = [w for w in words if w not in stopwords.words("english")]
    lemmatizer = WordNetLemmatizer()
    clean_tokens = [lemmatizer.lemmatize(w).lower().strip() for w in tokens]
    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('mrf',  MultiOutputClassifier(RandomForestClassifier()))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)
pipeline.fit(X_train, y_train)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x304e03160>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('mrf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier()))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_pred = pipeline.predict(X_test)
for ind, column in enumerate(y_test.columns):
    print(classification_report(np.array(y_test[column]), y_pred[:,ind]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.33      0.45      1523
#            1       0.82      0.96      0.89      4984
#
#     accuracy                           0.81      6507
#    macro avg       0.76      0.64      0.67      6507
# weighted avg       0.80      0.81      0.78      6507
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      5406
#            1       0.85      0.48      0.62      1101
#
#     accuracy                           0.90      6507
#    macro avg       0.88      0.73      0.78      6507
# weighted avg       0.89      0.90      0.89      6507
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6474
#            1       0.00      0.00      0.00        33
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82      3812
#            1       0.75      0.69      0.72      2695
#
#     accuracy                           0.78      6507
#    macro avg       0.77      0.77      0.77      6507
# weighted avg       0.78      0.78      0.78      6507
#
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      5979
#            1       0.58      0.05      0.10       528
#
#     accuracy                           0.92      6507
#    macro avg       0.75      0.52      0.53      6507
# weighted avg       0.90      0.92      0.89      6507
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6148
#            1       0.81      0.08      0.15       359
#
#     accuracy                           0.95      6507
#    macro avg       0.88      0.54      0.56      6507
# weighted avg       0.94      0.95      0.93      6507
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6317
#            1       0.70      0.04      0.07       190
#
#     accuracy                           0.97      6507
#    macro avg       0.84      0.52      0.53      6507
# weighted avg       0.96      0.97      0.96      6507
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6385
#            1       0.33      0.01      0.02       122
#
#     accuracy                           0.98      6507
#    macro avg       0.66      0.50      0.50      6507
# weighted avg       0.97      0.98      0.97      6507
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6301
#            1       0.49      0.09      0.15       206
#
#     accuracy                           0.97      6507
#    macro avg       0.73      0.54      0.57      6507
# weighted avg       0.96      0.97      0.96      6507
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6507
#
#     accuracy                           1.00      6507
#    macro avg       1.00      1.00      1.00      6507
# weighted avg       1.00      1.00      1.00      6507
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6098
#            1       0.85      0.32      0.46       409
#
#     accuracy                           0.95      6507
#    macro avg       0.90      0.66      0.72      6507
# weighted avg       0.95      0.95      0.94      6507
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      5802
#            1       0.82      0.58      0.67       705
#
#     accuracy                           0.94      6507
#    macro avg       0.88      0.78      0.82      6507
# weighted avg       0.94      0.94      0.94      6507
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      5933
#            1       0.84      0.30      0.45       574
#
#     accuracy                           0.93      6507
#    macro avg       0.89      0.65      0.71      6507
# weighted avg       0.93      0.93      0.92      6507
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6419
#            1       0.78      0.08      0.14        88
#
#     accuracy                           0.99      6507
#    macro avg       0.88      0.54      0.57      6507
# weighted avg       0.98      0.99      0.98      6507
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6358
#            1       0.83      0.03      0.06       149
#
#     accuracy                           0.98      6507
#    macro avg       0.91      0.52      0.53      6507
# weighted avg       0.97      0.98      0.97      6507
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6424
#            1       1.00      0.02      0.05        83
#
#     accuracy                           0.99      6507
#    macro avg       0.99      0.51      0.52      6507
# weighted avg       0.99      0.99      0.98      6507
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6265
#            1       0.75      0.02      0.05       242
#
#     accuracy                           0.96      6507
#    macro avg       0.86      0.51      0.51      6507
# weighted avg       0.96      0.96      0.95      6507
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6210
#            1       0.83      0.15      0.25       297
#
#     accuracy                           0.96      6507
#    macro avg       0.90      0.57      0.62      6507
# weighted avg       0.95      0.96      0.95      6507
#
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5642
#            1       0.66      0.03      0.06       865
#
#     accuracy                           0.87      6507
#    macro avg       0.76      0.51      0.49      6507
# weighted avg       0.84      0.87      0.81      6507
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6099
#            1       0.00      0.00      0.00       408
#
#     accuracy                           0.94      6507
#    macro avg       0.47      0.50      0.48      6507
# weighted avg       0.88      0.94      0.91      6507
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6206
#            1       0.71      0.08      0.14       301
#
#     accuracy                           0.96      6507
#    macro avg       0.83      0.54      0.56      6507
# weighted avg       0.95      0.96      0.94      6507
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6167
#            1       0.74      0.14      0.23       340
#
#     accuracy                           0.95      6507
#    macro avg       0.85      0.57      0.60      6507
# weighted avg       0.94      0.95      0.94      6507
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6362
#            1       1.00      0.03      0.07       145
#
#     accuracy                           0.98      6507
#    macro avg       0.99      0.52      0.53      6507
# weighted avg       0.98      0.98      0.97      6507
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6469
#            1       0.00      0.00      0.00        38
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6439
#            1       1.00      0.01      0.03        68
#
#     accuracy                           0.99      6507
#    macro avg       0.99      0.51      0.51      6507
# weighted avg       0.99      0.99      0.98      6507
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6487
#            1       0.00      0.00      0.00        20
#
#     accuracy                           1.00      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      1.00      1.00      6507
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6443
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.98      0.99      0.99      6507
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6224
#            1       0.00      0.00      0.00       283
#
#     accuracy                           0.96      6507
#    macro avg       0.48      0.50      0.49      6507
# weighted avg       0.91      0.96      0.94      6507
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      4694
#            1       0.85      0.69      0.76      1813
#
#     accuracy                           0.88      6507
#    macro avg       0.87      0.82      0.84      6507
# weighted avg       0.88      0.88      0.88      6507
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      5957
#            1       0.92      0.41      0.57       550
#
#     accuracy                           0.95      6507
#    macro avg       0.93      0.71      0.77      6507
# weighted avg       0.95      0.95      0.94      6507
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      5930
#            1       0.74      0.47      0.58       577
#
#     accuracy                           0.94      6507
#    macro avg       0.85      0.73      0.77      6507
# weighted avg       0.93      0.94      0.93      6507
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6440
#            1       1.00      0.01      0.03        67
#
#     accuracy                           0.99      6507
#    macro avg       0.99      0.51      0.51      6507
# weighted avg       0.99      0.99      0.98      6507
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5864
#            1       0.90      0.77      0.83       643
#
#     accuracy                           0.97      6507
#    macro avg       0.94      0.88      0.91      6507
# weighted avg       0.97      0.97      0.97      6507
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6371
#            1       0.70      0.05      0.10       136
#
#     accuracy                           0.98      6507
#    macro avg       0.84      0.53      0.54      6507
# weighted avg       0.97      0.98      0.97      6507
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6161
#            1       0.92      0.03      0.06       346
#
#     accuracy                           0.95      6507
#    macro avg       0.93      0.52      0.52      6507
# weighted avg       0.95      0.95      0.92      6507
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      5265
#            1       0.80      0.35      0.49      1242
#
#     accuracy                           0.86      6507
#    macro avg       0.83      0.67      0.71      6507
# weighted avg       0.85      0.86      0.84      6507
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(tokenizer=<function tokenize at 0x304e03160>)),
#   ('tfidf', TfidfTransformer()),
#   ('mrf', MultiOutputClassifier(estimator=RandomForestClassifier()))],
#  'verbose': False,
#  'vect': CountVectorizer(tokenizer=<function tokenize at 0x304e03160>),
#  'tfidf': TfidfTransformer(),
#  'mrf': MultiOutputClassifier(estimator=RandomForestClassifier()),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': <function __main__.tokenize(text)>,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'mrf__estimator__bootstrap': True,
#  'mrf__estimator__ccp_alpha': 0.0,
#  'mrf__estimator__class_weight': None,
#  'mrf__estimator__criterion': 'gini',
#  'mrf__estimator__max_depth': None,
#  'mrf__estimator__max_features': 'sqrt',
#  'mrf__estimator__max_leaf_nodes': None,
#  'mrf__estimator__max_samples': None,
#  'mrf__estimator__min_impurity_decrease': 0.0,
#  'mrf__estimator__min_samples_leaf': 1,
#  'mrf__estimator__min_samples_split': 2,
#  'mrf__estimator__min_weight_fraction_leaf': 0.0,
#  'mrf__estimator__n_estimators': 100,
#  'mrf__estimator__n_jobs': None,
#  'mrf__estimator__oob_score': False,
#  'mrf__estimator__random_state': None,
#  'mrf__estimator__verbose': 0,
#  'mrf__estimator__warm_start': False,
#  'mrf__estimator': RandomForestClassifier(),
#  'mrf__n_jobs': None}

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'mrf__estimator__n_estimators': [10, 20]}

#['estimator__bootstrap', 'estimator__class_weight', 'estimator__criterion', 'estimator__max_depth', 'estimator__max_features', 'estimator__max_leaf_nodes', 'estimator__min_impurity_decrease', 'estimator__min_impurity_split', 'estimator__min_samples_leaf', 'estimator__min_samples_split', 'estimator__min_weight_fraction_leaf', 'estimator__n_estimators', 'estimator__n_jobs', 'estimator__oob_score', 'estimator__random_state', 'estimator__verbose', 'estimator__warm_start', 'estimator', 'n_jobs']

cv = GridSearchCV(pipeline, parameters)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
cv.fit(X_train, y_train)
y_pred = cv.predict(X_test)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/udacity/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
(y_pred==y_test).mean()
# Out:
# related                   0.809897
# request                   0.894114
# offer                     0.994929
# aid_related               0.756109
# medical_help              0.920701
# medical_products          0.946365
# search_and_rescue         0.971262
# security                  0.981097
# military                  0.969264
# child_alone               1.000000
# water                     0.952359
# food                      0.932995
# shelter                   0.928385
# clothing                  0.987706
# money                     0.977409
# missing_people            0.987398
# refugees                  0.963731
# death                     0.960043
# other_aid                 0.868757
# infrastructure_related    0.937145
# transport                 0.956047
# buildings                 0.951130
# electricity               0.978024
# tools                     0.994160
# hospitals                 0.989550
# shops                     0.996926
# aid_centers               0.990164
# other_infrastructure      0.956355
# weather_related           0.867988
# floods                    0.947441
# storm                     0.938835
# fire                      0.990011
# earthquake                0.968495
# cold                      0.980175
# other_weather             0.947749
# direct_report             0.852313
# dtype: float64

# %%
cv.best_params_
# Out:
# {'mrf__estimator__n_estimators': 20}

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
import pickle
pickle.dump(cv, open("cv.p", "wb"))
